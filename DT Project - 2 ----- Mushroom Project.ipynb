# %%
import pandas as pd
import warnings
warnings.filterwarnings('ignore')

# %%
df = pd.read_csv('mushrooms.csv')
df.head()
# Out:
#   class cap-shape cap-surface cap-color bruises odor gill-attachment  \
# 0     p         x           s         n       t    p               f
# 1     e         x           s         y       t    a               f
# 2     e         b           s         w       t    l               f
# 3     p         x           y         w       t    p               f
# 4     e         x           s         g       f    n               f
#
#   gill-spacing gill-size gill-color  ... stalk-surface-below-ring  \
# 0            c         n          k  ...                        s
# 1            c         b          k  ...                        s
# 2            c         b          n  ...                        s
# 3            c         n          n  ...                        s
# 4            w         b          k  ...                        s
#
#   stalk-color-above-ring stalk-color-below-ring veil-type veil-color  \
# 0                      w                      w         p          w
# ...

# %%
df.columns
# Out:
# Index(['class', 'cap-shape', 'cap-surface', 'cap-color', 'bruises', 'odor',
#        'gill-attachment', 'gill-spacing', 'gill-size', 'gill-color',
#        'stalk-shape', 'stalk-root', 'stalk-surface-above-ring',
#        'stalk-surface-below-ring', 'stalk-color-above-ring',
#        'stalk-color-below-ring', 'veil-type', 'veil-color', 'ring-number',
#        'ring-type', 'spore-print-color', 'population', 'habitat'],
#       dtype='object')

# %%
df['class'].value_counts()
# Out:
# e    4208
# p    3916
# Name: class, dtype: int64

# %% [markdown]
# Checking how many different types of classes/lables exist in the dataset

# %%
df.describe()
# Out:
#        class cap-shape cap-surface cap-color bruises  odor gill-attachment  \
# count   8124      8124        8124      8124    8124  8124            8124
# unique     2         6           4        10       2     9               2
# top        e         x           y         n       f     n               f
# freq    4208      3656        3244      2284    4748  3528            7914
#
#        gill-spacing gill-size gill-color  ... stalk-surface-below-ring  \
# count          8124      8124       8124  ...                     8124
# unique            2         2         12  ...                        4
# top               c         b          b  ...                        s
# freq           6812      5612       1728  ...                     4936
#
#        stalk-color-above-ring stalk-color-below-ring veil-type veil-color  \
# count                    8124                   8124      8124       8124
# unique                      9                      9         1          4
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8124 entries, 0 to 8123
# Data columns (total 23 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   class                     8124 non-null   object
#  1   cap-shape                 8124 non-null   object
#  2   cap-surface               8124 non-null   object
#  3   cap-color                 8124 non-null   object
#  4   bruises                   8124 non-null   object
#  5   odor                      8124 non-null   object
#  6   gill-attachment           8124 non-null   object
#  7   gill-spacing              8124 non-null   object
#  8   gill-size                 8124 non-null   object
#  9   gill-color                8124 non-null   object
#  10  stalk-shape               8124 non-null   object
#  11  stalk-root                8124 non-null   object
#  12  stalk-surface-above-ring  8124 non-null   object
# ...

# %%
df.isna().sum()
# Out:
# class                       0
# cap-shape                   0
# cap-surface                 0
# cap-color                   0
# bruises                     0
# odor                        0
# gill-attachment             0
# gill-spacing                0
# gill-size                   0
# gill-color                  0
# stalk-shape                 0
# stalk-root                  0
# stalk-surface-above-ring    0
# stalk-surface-below-ring    0
# stalk-color-above-ring      0
# stalk-color-below-ring      0
# veil-type                   0
# veil-color                  0
# ring-number                 0
# ring-type                   0
# spore-print-color           0
# population                  0
# habitat                     0
# dtype: int64

# %% [markdown]
# No Null values in any of the columns

# %%
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()

for i in df.columns:
    df[i] = le.fit_transform(df[i])
    
df
# Out:
#       class  cap-shape  cap-surface  cap-color  bruises  odor  \
# 0         1          5            2          4        1     6
# 1         0          5            2          9        1     0
# 2         0          0            2          8        1     3
# 3         1          5            3          8        1     6
# 4         0          5            2          3        0     5
# ...     ...        ...          ...        ...      ...   ...
# 8119      0          3            2          4        0     5
# 8120      0          5            2          4        0     5
# 8121      0          2            2          4        0     5
# 8122      1          3            3          4        0     8
# 8123      0          5            2          4        0     5
#
#       gill-attachment  gill-spacing  gill-size  gill-color  ...  \
# 0                   1             0          1           4  ...
# 1                   1             0          0           4  ...
# ...

# %% [markdown]
# As all the columns were in text, hence did encoding using LabelEncoder for each text column to convert it into number

# %%
x = df.drop('class',axis=1)
y = df['class']

# %%
x
# Out:
#       cap-shape  cap-surface  cap-color  bruises  odor  gill-attachment  \
# 0             5            2          4        1     6                1
# 1             5            2          9        1     0                1
# 2             0            2          8        1     3                1
# 3             5            3          8        1     6                1
# 4             5            2          3        0     5                1
# ...         ...          ...        ...      ...   ...              ...
# 8119          3            2          4        0     5                0
# 8120          5            2          4        0     5                0
# 8121          2            2          4        0     5                0
# 8122          3            3          4        0     8                1
# 8123          5            2          4        0     5                0
#
#       gill-spacing  gill-size  gill-color  stalk-shape  ...  \
# ...

# %%
y
# Out:
# 0       1
# 1       0
# 2       0
# 3       1
# 4       0
#        ..
# 8119    0
# 8120    0
# 8121    0
# 8122    1
# 8123    0
# Name: class, Length: 8124, dtype: int64

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test = train_test_split( x, y, test_size=0.25, random_state=25 )

# %%
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import accuracy_score
import numpy as np
import matplotlib.pyplot as plt

error_rate = []
for i in range(1,40):
    knn = KNeighborsClassifier(n_neighbors = i)
    knn.fit(x_train,y_train)
    pred_i = knn.predict(x_test)
    error_rate.append(np.mean( pred_i != y_test ))

plt.figure( figsize = (10,6) )
plt.plot( range(1,40), error_rate )

# %% [markdown]
# Fetching error rate for k = 1 to 40 and will check K value where error rate is minimum.
# Seems like error rate is minimu i.e. 0 at K = 5

# %%
error_rate
# Out:
# [0.0004923682914820286,
#  0.0014771048744460858,
#  0.0009847365829640572,
#  0.0009847365829640572,
#  0.0,
#  0.0009847365829640572,
#  0.0019694731659281144,
#  0.0019694731659281144,
#  0.0014771048744460858,
#  0.002461841457410143,
#  0.0019694731659281144,
#  0.0034465780403741997,
#  0.0019694731659281144,
#  0.003938946331856229,
#  0.0034465780403741997,
#  0.004431314623338257,
#  0.0034465780403741997,
#  0.003938946331856229,
#  0.0034465780403741997,
#  0.004923682914820286,
#  0.004431314623338257,
#  0.006400787789266372,
#  0.006400787789266372,
#  0.009847365829640572,
#  0.008370260955194485,
#  0.012309207287050714,
#  0.011324470704086657,
#  0.012801575578532743,
#  0.011816838995568686,
#  0.012801575578532743,
#  0.012801575578532743,
#  0.013786312161496799,
#  0.013786312161496799,
#  0.015755785327424915,
#  0.01674052191038897,
#  0.01772525849335303,
#  0.018217626784835055,
#  0.019202363367799114,
#  0.018709995076317085]

# %%
error_rate = []
knn = KNeighborsClassifier(n_neighbors = 5)
knn.fit(x_train,y_train)
y_pred = knn.predict(x_test)
error_rate.append(np.mean( y_pred != y_test ))

error_rate
# Out:
# [0.0]

# %% [markdown]
# Just confirming the error rate by entering K = 5

# %%
from sklearn.metrics import confusion_matrix

print(confusion_matrix(y_test,y_pred))
print('Test accuracy:-',accuracy_score(y_test,y_pred))
# Out:
# [[1046    0]
#  [   0  985]]
# Test accuracy:- 1.0

# %% [markdown]
# Accuracy is 100 %, also no False Positive or False Negative, seems Model is working fine.

# %%
import numpy as np
df_pred = np.array(y_pred)
df_actual = np.array(y_test)
analysis = pd.DataFrame({"Predicted Value" : df_pred, "Actual value" : df_actual, "Difference": df_pred - df_actual})
analysis
# Out:
#       Predicted Value  Actual value  Difference
# 0                   0             0           0
# 1                   1             1           0
# 2                   0             0           0
# 3                   0             0           0
# 4                   0             0           0
# ...               ...           ...         ...
# 2026                0             0           0
# 2027                1             1           0
# 2028                0             0           0
# 2029                1             1           0
# 2030                0             0           0
#
# [2031 rows x 3 columns]

# %% [markdown]
# Comparing predicted value and actual test value by creating a dataframe.

# %%
analysis["Difference"].value_counts()
# Out:
# 0    2031
# Name: Difference, dtype: int64

# %% [markdown]
# Checking different values of Difference column, seems all values are zero, which means every preidcted value has been predicted correctly and is matching with the test value. Great !

# %%
import pickle
filename = 'mushroom_project.pkl'
pickle.dump(knn, open(filename, 'wb' ))

# %% [markdown]
# Saving the model

# %%
filename = 'mushroom_project.pkl'
loaded_model = pickle.load(open(filename, 'rb'))
result = loaded_model.score(x_test, y_test)
print(result)
# Out:
# 1.0

# %% [markdown]
# Trying to Load the model just to check if saved model is working or not
